# %%
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar
from PIL import Image, ImageDraw

pil_base = Image.open('img/base.png')
(width, height) = pil_base.size
print('Width: %d' % width)
print('Height: %d' % height)
display(pil_base)
# Out:
# Width: 509
# Height: 722
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=509x722 at 0x7F4F57204F98>

# %%
dpi = 100
plt.axis('tight')
figsize = (width/dpi, height/dpi)
fig = plt.figure(figsize=figsize, dpi=dpi)

plt.imshow(pil_base)

# %%
plt.axis('tight')
scalebar = ScaleBar(20000) # 1 pixel = 0.2 meter
plt.gca().add_artist(scalebar)

plt.imshow(pil_base)

# %%
plt.imshow(pil_base)

# %%
#plt.axis('on')
plt.gca().add_artist(scalebar)
plt.imshow(pil_base)
# Out:
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# <ipython-input-18-6a6350b18106> in <module>
#       1 #plt.axis('on')
# ----> 2 plt.gca().add_artist(scalebar)
#       3 plt.imshow(pil_base)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in add_artist(self, a)
#    1721         Returns the artist.
#    1722         """
# -> 1723         a.axes = self
#    1724         self.artists.append(a)
#    1725         self._set_artist_props(a)
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in axes(self, new_axes)
#     212         if (new_axes is not None and self._axes is not None
#     213                 and new_axes != self._axes):
# --> 214             raise ValueError("Can not reset the axes.  You are probably "
#     215                              "trying to re-use an artist in more than one "
#     216                              "Axes which is not supported")
#
# ValueError: Can not reset the axes.  You are probably trying to re-use an artist in more than one Axes which is not supported
